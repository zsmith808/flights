# %%
import pandas as pd
import numpy as np

# %%
flights = pd.read_csv('filtered_flights.csv')

# %%
flights.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  3a82a9a5d5024e19d2aad00cf15825d2  2022-09-28  2022-11-12             LAX
# 1  15881d68ee29ae6603a38d2d2ff8f619  2022-04-22  2022-06-20             BOS
# 2  cef40123e9d4e37ad5cee3fda6a9b2cd  2022-07-15  2022-07-26             MIA
# 3  c1fb1fa3dafa44e3d9fee5d03a2340d9  2022-08-01  2022-09-19             MIA
# 4  a9e4d598a6ad88e2fbb800691066224b  2022-04-22  2022-06-11             SFO
#
#   destinationAirport fareBasisCode travelDuration  elapsedDays  \
# 0                JFK      LAVOA0BC        PT5H31M            0
# 1                LAX      M0AJZNN1        PT8H14M            0
# 2                LAX      L3AHZNN1         PT5H4M            0
# 3                LAX         UA3NR       PT13H39M            1
# 4                LAX      ZL4AUEL1        PT1H28M            0
#
#    isBasicEconomy  isRefundable  ...  segmentsArrivalTimeEpochSeconds  \
# ...

# %%
#removed the ID column 
flights = flights.drop(columns=['legId'])

# %%
flights.head()
# Out:
#    searchDate  flightDate startingAirport destinationAirport fareBasisCode  \
# 0  2022-09-28  2022-11-12             LAX                JFK      LAVOA0BC
# 1  2022-04-22  2022-06-20             BOS                LAX      M0AJZNN1
# 2  2022-07-15  2022-07-26             MIA                LAX      L3AHZNN1
# 3  2022-08-01  2022-09-19             MIA                LAX         UA3NR
# 4  2022-04-22  2022-06-11             SFO                LAX      ZL4AUEL1
#
#   travelDuration  elapsedDays  isBasicEconomy  isRefundable  isNonStop  ...  \
# 0        PT5H31M            0            True         False       True  ...
# 1        PT8H14M            0           False         False      False  ...
# 2         PT5H4M            0           False         False       True  ...
# 3       PT13H39M            1           False         False      False  ...
# 4        PT1H28M            0           False         False       True  ...
#
#    segmentsArrivalTimeEpochSeconds  \
# ...
